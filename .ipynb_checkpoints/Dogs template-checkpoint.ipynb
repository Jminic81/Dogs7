# %% [markdown]
# # Largest Dog Breed Dataset
# ### Kaggle submission by Liam Larsen
#
# The 2016 dataset lists the type of dog license issued to owners located in 131 different zip codes in Pennsylvania.  For each license issued, the breed type, color, and name of the dog is specified.
#
# Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
sns.set(style="white", color_codes=True)

# %% [markdown]
# Import data set

# %%
data = pd.read_csv("2016.csv")

# %% [markdown]
# Verify data is loaded, confirm all rows were loaded.  The data provided under "Column Metrics" in Kaggle agrees with the result below; 27018 rows, 7 columns.

# %%
data.shape
# Out:
# (27018, 7)

# %% [markdown]
# View column headings and the first five rows of the dataset.  Or change the number of rows to view by enterings a number in ().

# %%
data.head()
# Out:
#                                       LicenseType                Breed  \
# 0                    Dog Individual Spayed Female         GOLDENDOODLE
# 1  Dog Senior Citizen or Disability Spayed Female            CHIHUAHUA
# 2                    Dog Individual Neutered Male  GER SHORTHAIR POINT
# 3         Dog Senior Citizen or Disability Female               BEAGLE
# 4         Dog Senior Citizen or Disability Female               BEAGLE
#
#                Color             DogName  OwnerZip  ExpYear         ValidDate
# 0               GOLD               TALLY     15227     2016   2/16/2016 14:55
# 1  WHITE/BLACK/BROWN             CHALUPA     15120     2016   1/11/2016 15:23
# 2            SPOTTED                JINX     15236     2016  12/22/2015 15:32
# 3              MULTI  JACKPINE JERUSALEM     15044     2016  12/17/2015 12:28
# 4              MULTI     JACKPINE JORDAN     15044     2016  12/17/2015 12:28

# %% [markdown]
# View the last five rows of the dataset.

# %%
data.tail()
# Out:
#                         LicenseType              Breed        Color  DogName  \
# 27013  Dog Individual Spayed Female       GER SHEPHERD        WHITE    GHOST
# 27014  Dog Individual Neutered Male     ROTTWEILER MIX  BLACK/BROWN  BUCKEYE
# 27015  Dog Individual Neutered Male          SIB HUSKY        BROWN    ROCCO
# 27016  Dog Individual Spayed Female              MIXED        BROWN     ECHO
# 27017      Dog Senior Lifetime Male  YORKSHIRE TERRIER    BLACK/TAN  SCRAPPY
#
#        OwnerZip  ExpYear         ValidDate
# 27013     15218     2016  12/13/2016 11:16
# 27014     15044     2016  12/13/2016 11:18
# 27015     15146     2016   12/19/2016 9:58
# 27016     15237     2016  12/19/2016 10:06
# 27017     15110     2016  12/23/2016 10:15

# %%
Check the data type.

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
Sample one variable.

# %%
data["Breed"].value_counts()
# Out:
# MIXED                   2941
# LABRADOR RETRIEVER      1787
# LAB MIX                 1598
# GER SHEPHERD             926
# AM PIT BULL TERRIER      872
# GOLDEN RETRIEVER         827
# CHIHUAHUA                776
# SHIH TZU                 754
# TAG                      685
# BEAGLE                   684
# YORKSHIRE TERRIER        633
# BOXER                    580
# BEAGLE MIX               555
# DACHSHUND                504
# GER SHEPHERD MIX         445
# AM PITT BULL MIX         338
# POMERANIAN               327
# PUG                      324
# TERRIER MIX              302
# MALTESE                  298
# BICHON FRISE             267
# YORKSHIRE TERR MIX       262
# BOXER MIX                255
# COCKER SPANIEL           253
# ROTTWEILER               242
# CHIHUAHUA MIX            238
# GOLDENDOODLE             236
# SIB HUSKY                226
# SHETLAND SHEEPDOG        225
# BOSTON TERRIER           201
#                         ...
# ENTLEBUCHER SENNEN         1
# ...

# %%
Column named "Breed" is set as the index column.

# %%
df1 = data.set_index('Breed')

df1
# Out:
#                                                         LicenseType  \
# Breed
# GOLDENDOODLE                           Dog Individual Spayed Female
# CHIHUAHUA            Dog Senior Citizen or Disability Spayed Female
# GER SHORTHAIR POINT                    Dog Individual Neutered Male
# BEAGLE                      Dog Senior Citizen or Disability Female
# BEAGLE                      Dog Senior Citizen or Disability Female
# W HGHLND WH TERRIER                    Dog Individual Spayed Female
# LAB MIX                                Dog Individual Spayed Female
# DACHSHUND                              Dog Individual Spayed Female
# ST BERNARD                                      Dog Individual Male
# LABRADOR RETRIEVER                     Dog Individual Spayed Female
# POODLE TOY           Dog Senior Citizen or Disability Spayed Female
# MIXED                              Dog Individual License Duplicate
# BOXER MIX                              Dog Individual Neutered Male
# ...

# %%
Group by and compute the sum.        >>>>FIGURE OUT HOW TO DO THIS WITH COUNT - 1 per row!  It only pulled in the columns w/ #.

# %%
df2 = df1.groupby('Breed').sum()

df2
# Out:
#                      OwnerZip  ExpYear
# Breed
# .                      408888    54432
# AFFENPINSCHER           15228     2016
# AFGHAN HOUND            15209     2016
# AIREDALE TERRIER       652627    86688
# AKITA                  332941    44352
# AKITA MIX              136636    18144
# ALAPAHA BLUE BULLDO     30237     4032
# ALAS KLEE KAI           30322     4032
# ALAS MALAMUTE          440077    58464
# ALPINE MASTIFF          30317     4032
# AM BLACK&TAN COONHO     60701     8064
# AM BULLDOG            2135958   284256
# AM ESKIMO DOG          954979   127008
# AM FOXHOUND            182124    24192
# AM PIT BULL TERRIER  13208380  1757952
# AM PITT BULL MIX      5120170   681408
# AM STAFF TERRIER       786953   104832
# AM TOY TERRIER         120965    16128
# AM WATER SPANIEL        75343    10080
# ANATOLIAN SHEPHERD      45700     6048
# ARGENTINO DOGO          30378     4032
# AUS CATTLE DOG        1091779   145152
# AUS KELPIE              15227     2016
# ...
