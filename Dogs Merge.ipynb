# %%
#Analysis and Visualization of the Largest Dog Breed Data Set; Liam Larsen's Kaggle submission.  
#The Readme contains original background and discussion of the data analysis in this Jupyter Notebook. 

#Import all libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings  #Chose to ignore the warnings that are printed by the Seaborn library
warnings.filterwarnings("ignore")
sns.set(style="white", color_codes=True)

# %%
#Read the first .csv file into data frame "df1".
df1=pd.read_csv("2016.csv")

# %%
#Determine number of rows and columns.
df1.shape
# Out:
# (27018, 7)

# %%
#View column names and the first five rows.  Verified all other .csv files contain the same column headings so additional
#.csv files can be simply merged.
df1.head()
# Out:
#                                       LicenseType                Breed  \
# 0                    Dog Individual Spayed Female         GOLDENDOODLE
# 1  Dog Senior Citizen or Disability Spayed Female            CHIHUAHUA
# 2                    Dog Individual Neutered Male  GER SHORTHAIR POINT
# 3         Dog Senior Citizen or Disability Female               BEAGLE
# 4         Dog Senior Citizen or Disability Female               BEAGLE
#
#                Color             DogName  OwnerZip  ExpYear         ValidDate
# 0               GOLD               TALLY     15227     2016   2/16/2016 14:55
# 1  WHITE/BLACK/BROWN             CHALUPA     15120     2016   1/11/2016 15:23
# 2            SPOTTED                JINX     15236     2016  12/22/2015 15:32
# 3              MULTI  JACKPINE JERUSALEM     15044     2016  12/17/2015 12:28
# 4              MULTI     JACKPINE JORDAN     15044     2016  12/17/2015 12:28

# %%
#View the last five rows and determine the ID for the last row (27017).
df1.tail()
# Out:
#                         LicenseType              Breed        Color  DogName  \
# 27013  Dog Individual Spayed Female       GER SHEPHERD        WHITE    GHOST
# 27014  Dog Individual Neutered Male     ROTTWEILER MIX  BLACK/BROWN  BUCKEYE
# 27015  Dog Individual Neutered Male          SIB HUSKY        BROWN    ROCCO
# 27016  Dog Individual Spayed Female              MIXED        BROWN     ECHO
# 27017      Dog Senior Lifetime Male  YORKSHIRE TERRIER    BLACK/TAN  SCRAPPY
#
#        OwnerZip  ExpYear         ValidDate
# 27013     15218     2016  12/13/2016 11:16
# 27014     15044     2016  12/13/2016 11:18
# 27015     15146     2016   12/19/2016 9:58
# 27016     15237     2016  12/19/2016 10:06
# 27017     15110     2016  12/23/2016 10:15

# %%
#Read the next nine .csv files into data frame "dfn" where n=2 through 9
df2=pd.read_csv("2015.csv")

# %%
df3=pd.read_csv("2014.csv")

# %%
df4=pd.read_csv("2013.csv")

# %%
df5=pd.read_csv("2012.csv")

# %%
df6=pd.read_csv("2011.csv")

# %%
df7=pd.read_csv("2010.csv")

# %%
df8=pd.read_csv("2009.csv")

# %%
df9=pd.read_csv("2008.csv")

# %%
df10=pd.read_csv("2007.csv")

# %%
#Merge the 10 .csv files into one data frame, df11.
df11=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])

# %%
df11.tail()
# Out:
#                         LicenseType               Breed        Color  \
# 29856  Dog Individual Spayed Female      LHASA APSO MIX  WHITE/BROWN
# 29857  Dog Individual Spayed Female           SIB HUSKY          RED
# 29858  Dog Individual Spayed Female          BEAGLE MIX      SPOTTED
# 29859  Dog Individual Neutered Male  LABRADOR RETRIEVER        BLACK
# 29860  Dog Individual Neutered Male           DACHSHUND    BLACK/TAN
#
#             DogName  OwnerZip  ExpYear        ValidDate
# 29856  BUTTERSCOTCH     16059     2007  3/12/2007 14:30
# 29857         RIKKU     16066     2007   2/2/2007 13:33
# 29858         MOLLY     16066     2007  5/17/2007 13:55
# 29859        SCOOBY     16229     2007    3/6/2007 8:59
# 29860        PEPPER     19350     2007   11/7/2007 8:34

# %%
df12 = df11.drop(df11.columns[[0,2,3,4,6]],axis=1)

# %%
df12.head()
df12["ExpYear"].value_counts()
df12["Breed"].value_counts()
mixed = df12[df12["Breed"] == "MIXED"]

# %%
mixed["ExpYear"].value_counts()
# Out:
# 2008    5388
# 2009    4566
# 2007    4046
# 2010    4005
# 2011    3789
# 2012    3646
# 2014    3643
# 2013    3540
# 2015    3438
# 2016    2941
# Name: ExpYear, dtype: int64

# %%
objects = ('2007','2008','2009','2010','2011','2012','2013','2014','2015','2016')

y_pos = np.arange(len(objects))

data = mixed["ExpYear"].value_counts()

plt.plot(y_pos, data, label = 'mixed')
plt.xticks(y_pos, objects,rotation=90)
plt.legend()
plt.show()

# %%
#Verify all rows are present.
df11.shape
# Out:
# (296837, 7)

# %%
#Verify all columns are present.
df11.columns
# Out:
# Index(['LicenseType', 'Breed', 'Color', 'DogName', 'OwnerZip', 'ExpYear',
#        'ValidDate'],
#       dtype='object')

# %%
#Flag cells that are blank.
df11.isnull()
# Out:
#        LicenseType  Breed  Color  DogName  OwnerZip  ExpYear  ValidDate
# 0            False  False  False    False     False    False      False
# 1            False  False  False    False     False    False      False
# 2            False  False  False    False     False    False      False
# 3            False  False  False    False     False    False      False
# 4            False  False  False    False     False    False      False
# 5            False  False  False    False     False    False      False
# 6            False  False  False    False     False    False      False
# 7            False  False  False    False     False    False      False
# 8            False  False  False    False     False    False      False
# 9            False  False  False    False     False    False      False
# 10           False  False  False    False     False    False      False
# 11           False  False  False    False     False    False      False
# 12           False  False  False    False     False    False      False
# 13           False  False  False    False     False    False      False
# 14           False  False  False    False     False    False      False
# 15           False  False  False    False     False    False      False
# 16           False  False  False    False     False    False      False
# 17           False  False  False    False     False    False      False
# 18           False  False  False    False     False    False      False
# 19           False  False  False    False     False    False      False
# 20           False  False  False    False     False    False      False
# 21           False  False  False    False     False    False      False
# 22           False  False  False    False     False    False      False
# 23           False  False  False    False     False    False      False
# 24           False  False  False    False     False    False      False
# 25           False  False  False    False     False    False      False
# 26           False  False  False    False     False    False      False
# 27           False  False  False    False     False    False      False
# 28           False  False  False    False     False    False      False
# 29           False  False  False    False     False    False      False
# ...            ...    ...    ...      ...       ...      ...        ...
# 29831        False  False  False    False     False    False      False
# 29832        False  False  False    False     False    False      False
# 29833        False  False  False    False     False    False      False
# 29834        False  False  False    False     False    False      False
# 29835        False  False  False    False     False    False      False
# 29836        False  False  False    False     False    False      False
# 29837        False  False  False    False     False    False      False
# 29838        False  False  False    False     False    False      False
# 29839        False  False  False    False     False    False      False
# 29840        False  False  False    False     False    False      False
# 29841        False  False  False    False     False    False      False
# 29842        False  False  False    False     False    False      False
# 29843        False  False  False    False     False    False      False
# 29844        False  False  False    False     False    False      False
# 29845        False  False  False    False     False    False      False
# 29846        False  False  False    False     False    False      False
# 29847        False  False  False    False     False    False      False
# 29848        False  False  False    False     False    False      False
# 29849        False  False  False    False     False    False      False
# 29850        False  False  False    False     False    False      False
# 29851        False  False  False    False     False    False      False
# 29852        False  False  False    False     False    False      False
# 29853        False  False  False    False     False    False      False
# 29854        False  False  False    False     False    False      False
# 29855        False  False  False    False     False    False      False
# 29856        False  False  False    False     False    False      False
# 29857        False  False  False    False     False    False      False
# 29858        False  False  False    False     False    False      False
# 29859        False  False  False    False     False    False      False
# 29860        False  False  False    False     False    False      False
#
# [296837 rows x 7 columns]

# %%
#Summarize the location and number of cells that are blank.  See Readme for discussion of cells that are not blank but do not
#contain valid data.
df11.isnull().sum()
# Out:
# LicenseType       0
# Breed             0
# Color             0
# DogName           0
# OwnerZip          0
# ExpYear           0
# ValidDate      1646
# dtype: int64

# %%
#Summarize breed count in decending order.
df11["Breed"].value_counts()
# Out:
# MIXED                             39002
# LABRADOR RETRIEVER                22536
# LAB MIX                           17136
# GOLDEN RETRIEVER                  10110
# AM PIT BULL TERRIER                9824
# BEAGLE                             9112
# GER SHEPHERD                       8987
# SHIH TZU                           7731
# CHIHUAHUA                          7170
# BOXER                              6598
# YORKSHIRE TERRIER                  6074
# DACHSHUND                          5771
# GER SHEPHERD MIX                   5533
# BEAGLE MIX                         5175
# PUG                                3841
# COCKER SPANIEL                     3743
# ROTTWEILER                         3372
# PARSON RUSSELL TERR                3339
# MALTESE                            3224
# BICHON FRISE                       3214
# AM PITT BULL MIX                   2997
# TERRIER MIX                        2984
# SHETLAND SHEEPDOG                  2975
# POMERANIAN                         2888
# SIB HUSKY                          2707
# TAG                                2629
# BOSTON TERRIER                     2267
# BOXER MIX                          2239
# SCHNAUZER MIN                      2169
# COCKAPOO                           2143
#                                   ...
# WATER DOG SPANISH                     2
# KANGAL DOG                            1
# Mountain Feist                        1
# EPAGNEUL PONT-AUDEM                   1
# BASSET GRIFFON VEND                   1
# BASSET GRIFFON VEND?EN (PETIT)        1
# ALPINE DACHSBRACKE                    1
# MIN-PEI                               1
# N AM AUS SHEPHERD                     1
# SHILLER HOUND                         1
# CIRNECO DELL ETNA                     1
# RUSSIAN TOY                           1
# PUMI                                  1
# PODENGO PORT MEDIO                    1
# TRANSYLVANIAN HOUND                   1
# SLOVENSKY CUVAC                       1
# BEAGLE HARRIER                        1
# W SIBERIAN LAIKA                      1
# PERUVIAN INCA ORCHID                  1
# KOOIKERHONDJE                         1
# PHARAOH HOUND                         1
# BELG LAEKENOIS                        1
# PYRENEAN SHEPHERD                     1
# SWEDISH VALLHUND                      1
# GREYHOUND SPANISH                     1
# KISHU                                 1
# PUPPY                                 1
# DANISH BROHOLMER                      1
# GRAND GRIFFON VENDE                   1
# PORT WIREHAIR PODENG                  1
# Name: Breed, Length: 344, dtype: int64

# %%
#Visualize breed count in descending order.  Limit results to top 20 only. 
dog_breed = pd.DataFrame(df11.groupby('Breed').size().sort_values(ascending=False).rename('Amount').reset_index())
f, ax = plt.subplots(figsize=(6, 15))

sns.barplot(x='Amount', y='Breed', data=dog_breed.head(20))
plt.savefig('dogbar.png',bbox_inches='tight')
plt.show()

# %%
#Show changes over time in breed count.
df12=df11.group_by(ExpYear)
x=ExpYear
y=dog_breed.head(20)
plt.plot([2007,2008,2009,2010,2011,2012,2013,2014,2015,2016])

plt.title("Breed Count by Year")
plt.xlabel('Year')
plt.ylabel('Breed')

plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-efaa55e09057> in <module>()
#       1 #Show changes over time in breed count.
# ----> 2 df12=df11.group_by(ExpYear)
#       3 x=ExpYear
#       4 y=dog_breed.head(20)
#       5 plt.plot([2007,2008,2009,2010,2011,2012,2013,2014,2015,2016])
#
# C:\Users\Judy\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'group_by'

# %%
#Summarize color count in descending order.
df11["Color"].value_counts()

# %%
#Summarize dog name count in descending order.
df11["DogName"].value_counts()

# %%
#Summarize zip code count in descending order.
df11["OwnerZip"].value_counts()
